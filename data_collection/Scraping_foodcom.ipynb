# %%
import requests
from bs4 import BeautifulSoup

# %%
def get_category_links(base_url):
    response = requests.get(base_url)
    if response.status_code !=200:
        print("failed to retrieve page")
        return []
    
    soup = BeautifulSoup(response.text, 'html.parser')
    magic_columns = soup.find_all('div', class_='letter-filters magic-buttons')
    links = magic_buttons.find_all('a')
    
   
    return magic_columns

# %%
get_category_links('https://www.food.com/topic')
# Out:
# [<div class="letter-filters magic-buttons">
#  <label class="js-selected" for="magic-chkbox"></label>
#  <input id="magic-chkbox" type="checkbox">
#  <ul></ul>
#  </input></div>]
